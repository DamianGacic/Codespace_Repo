# %%
import pandas as pd
import numpy as np

# %%
# Specify the path to your CSV file
csv_file_path = 'shell.csv'

# Initialize an empty list to store valid lines
valid_lines = []

# Read the file line by line
with open('shell.csv', 'r') as file:
        try:
            # Try to parse the line as a CSV record
            record = pd.read_csv('shell.csv')
            valid_lines.append(record)
        except pd.errors.ParserError as e:
            # Handle the parsing error (e.g., print a warning)
            print(f"Skipped line due to parsing error: {line.strip()}")

# Concatenate valid lines into a DataFrame
df = pd.concat(valid_lines, ignore_index=True)

#df = df.iloc[:122]
# Display the DataFrame
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df
df.to_csv("cleaner_shell.csv")

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.read_csv("shell.csv")

#df = df.iloc[:122]
df
# Out:
#          TYPE TEST                                         INPUT USER  \
# 0               CD                               cd ../../../../../..
# 1               CD                                               cd ~
# 2               CD                                                 cd
# 3               CD                                       cd ~/Desktop
# 4               CD                                  unset HOME - cd ~
# 5               CD                   export HOME=/Users/user42 - cd ~
# 6               CD                                    cd .. cool swag
# 7               CD                                         cd Eyooooo
# 8               CD                                               cd -
# 9               CD                                               cd -
# 10              CD  mkdir a - mkdir a/b - cd a/b - rm -r ../../a -...
# 11            ECHO                                               echo
# ...

# %%
df = pd.read_csv("csv.ipynb", error_bad_lines=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /workspaces/CS_from_Repo_test/csv.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell://codespaces%2Bfantastic-bassoon-wrrp47w5rxxw35449/workspaces/CS_from_Repo_test/csv.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> df = pd.read_csv("csv.ipynb", error_bad_lines=False)
#
# TypeError: read_csv() got an unexpected keyword argument 'error_bad_lines'
